# %% [markdown]
# # Oktoberfest_MSFragger
#
#
# # 1. A1101

# %% [markdown]
# ### improt packages

# %%
import pandas
import re

# %% [markdown]
# ## target peptides

# %%
rescore_peptides_A1101 = pandas.read_csv("/home/thinkpad/HLA_Files/A1101/A1101_Oktoberfest_MSFragger/results/percolator/rescore_target.peptides", sep= '\t')

# %%
rescore_peptides_A1101
# Out:
#                                                    PSMId    score   q-value  \
# 0      AC20171011_Broad_HLA_A1101_R1_Rep02-3085-RVYDP...  2.05516  0.000617
# 1      YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-121...  1.97562  0.000617
# 2      YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-807...  1.64188  0.000617
# 3      YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-149...  1.63419  0.000617
# 4      AC20171011_Broad_HLA_A1101_R2_Rep02-6551-GTFQL...  1.62390  0.000617
# ...                                                  ...      ...       ...
# 14100  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-440... -3.30983  0.572614
# 14101  AC20171011_Broad_HLA_A1101_R1_Rep02-30819-NKIT... -3.33715  0.572614
# 14102  AC20171011_Broad_HLA_A1101_R2_Rep01-26832-ILMG... -3.42819  0.572674
# 14103  AC20171011_Broad_HLA_A1101_R2_Rep01-28172-TQEA... -3.45047  0.572674
# 14104  AC20171011_Broad_HLA_A1101_R1_Rep02-25756-LGTG... -5.07269  0.572776
#
#        posterior_error_prob                    peptide             proteinIds
# 0              7.349330e-09            _.RVYDPASPQRR._            RVYDPASPQRR
# 1              1.517670e-08            _.ISDPTSPLRTR._            ISDPTSPLRTR
# 2              3.182080e-07  _.RTGPPM[UNIMOD:35]GSRF._  RTGPPM[UNIMOD:35]GSRF
# 3              3.412970e-07        _.GISEETTTGVHNLYK._        GISEETTTGVHNLYK
# 4              3.748810e-07         _.GTFQLNSKDQGLQK._         GTFQLNSKDQGLQK
# ...                     ...                        ...                    ...
# 14100          1.000000e+00            _.KVGAAGGARGV._            KVGAAGGARGV
# 14101          1.000000e+00               _.NKITELPK._               NKITELPK
# 14102          1.000000e+00          _.ILMGSTLRKRKMY._          ILMGSTLRKRKMY
# 14103          1.000000e+00          _.TQEALSIHGVKEA._          TQEALSIHGVKEA
# 14104          1.000000e+00        _.LGTGRGTLRLRSRGP._        LGTGRGTLRLRSRGP
#
# [14105 rows x 6 columns]

# %%
print (rescore_peptides_A1101.PSMId.unique ,'\n \n') 
print (rescore_peptides_A1101.peptide.unique ,'\n \n')
print (rescore_peptides_A1101.proteinIds.unique)
# Out:
# <bound method Series.unique of 0        AC20171011_Broad_HLA_A1101_R1_Rep02-3085-RVYDP...
# 1        YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-121...
# 2        YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-807...
# 3        YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-149...
# 4        AC20171011_Broad_HLA_A1101_R2_Rep02-6551-GTFQL...
#                                ...
# 14100    YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-440...
# 14101    AC20171011_Broad_HLA_A1101_R1_Rep02-30819-NKIT...
# 14102    AC20171011_Broad_HLA_A1101_R2_Rep01-26832-ILMG...
# 14103    AC20171011_Broad_HLA_A1101_R2_Rep01-28172-TQEA...
# 14104    AC20171011_Broad_HLA_A1101_R1_Rep02-25756-LGTG...
# Name: PSMId, Length: 14105, dtype: object>
#
#
# <bound method Series.unique of 0                  _.RVYDPASPQRR._
# 1                  _.ISDPTSPLRTR._
# 2        _.RTGPPM[UNIMOD:35]GSRF._
# 3              _.GISEETTTGVHNLYK._
# 4               _.GTFQLNSKDQGLQK._
#                    ...
# 14100              _.KVGAAGGARGV._
# 14101                 _.NKITELPK._
# 14102            _.ILMGSTLRKRKMY._
# 14103            _.TQEALSIHGVKEA._
# 14104          _.LGTGRGTLRLRSRGP._
# Name: peptide, Length: 14105, dtype: object>
#
#
# <bound method Series.unique of 0                  RVYDPASPQRR
# 1                  ISDPTSPLRTR
# 2        RTGPPM[UNIMOD:35]GSRF
# 3              GISEETTTGVHNLYK
# 4               GTFQLNSKDQGLQK
#                  ...
# 14100              KVGAAGGARGV
# 14101                 NKITELPK
# 14102            ILMGSTLRKRKMY
# 14103            TQEALSIHGVKEA
# 14104          LGTGRGTLRLRSRGP
# Name: proteinIds, Length: 14105, dtype: object>

# %% [markdown]
# ### filter the dataset with FDR = 0.01

# %%
filtered_peptide_A1101 = rescore_peptides_A1101[rescore_peptides_A1101['q-value'] <= 0.01]

# modify the peptide in a new column
filtered_peptide_A1101["modi_peptide"] = filtered_peptide_A1101['peptide']

filtered_peptide_A1101
# Out:
# /tmp/ipykernel_235831/2715835033.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_A1101["modi_peptide"] = filtered_peptide_A1101['peptide']
#                                                   PSMId     score   q-value  \
# 0     AC20171011_Broad_HLA_A1101_R1_Rep02-3085-RVYDP...  2.055160  0.000617
# 1     YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-121...  1.975620  0.000617
# 2     YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-807...  1.641880  0.000617
# 3     YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-149...  1.634190  0.000617
# 4     AC20171011_Broad_HLA_A1101_R2_Rep02-6551-GTFQL...  1.623900  0.000617
# ...                                                 ...       ...       ...
# 5996  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-102...  0.197624  0.009998
# 5997  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-173...  0.197569  0.009998
# 5998  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-103...  0.197401  0.009998
# 5999  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-962...  0.197330  0.009998
# 6000  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-174...  0.196884  0.009998
#
#       posterior_error_prob                    peptide             proteinIds  \
# 0             7.349330e-09            _.RVYDPASPQRR._            RVYDPASPQRR
# 1             1.517670e-08            _.ISDPTSPLRTR._            ISDPTSPLRTR
# 2             3.182080e-07  _.RTGPPM[UNIMOD:35]GSRF._  RTGPPM[UNIMOD:35]GSRF
# 3             3.412970e-07        _.GISEETTTGVHNLYK._        GISEETTTGVHNLYK
# 4             3.748810e-07         _.GTFQLNSKDQGLQK._         GTFQLNSKDQGLQK
# ...                    ...                        ...                    ...
# 5996          1.367470e-01              _.SSPQAGSSL._              SSPQAGSSL
# 5997          1.368040e-01          _.TVFYPSDGVATEK._          TVFYPSDGVATEK
# 5998          1.369730e-01             _.SVISRPIVQK._             SVISRPIVQK
# 5999          1.370460e-01               _.IDGSVNPK._               IDGSVNPK
# 6000          1.375000e-01            _.ASYPGASVDNY._            ASYPGASVDNY
#
#                    modi_peptide
# 0               _.RVYDPASPQRR._
# 1               _.ISDPTSPLRTR._
# 2     _.RTGPPM[UNIMOD:35]GSRF._
# 3           _.GISEETTTGVHNLYK._
# 4            _.GTFQLNSKDQGLQK._
# ...                         ...
# 5996              _.SSPQAGSSL._
# 5997          _.TVFYPSDGVATEK._
# 5998             _.SVISRPIVQK._
# 5999               _.IDGSVNPK._
# 6000            _.ASYPGASVDNY._
#
# [6001 rows x 7 columns]

# %%
filtered_peptide_A1101['modi_peptide'] = filtered_peptide_A1101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_peptide_A1101['modi_peptide'] = filtered_peptide_A1101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_peptide_A1101.tail(20)
# Out:
# /tmp/ipykernel_235831/4249490402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_A1101['modi_peptide'] = filtered_peptide_A1101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/4249490402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_A1101['modi_peptide'] = filtered_peptide_A1101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                   PSMId     score   q-value  \
# 5981  AC20171011_Broad_HLA_A1101_R2_Rep02-4527-ALTIH...  0.203667  0.009694
# 5982  AC20171011_Broad_HLA_A1101_R2_Rep01-6203-PSTPI...  0.203651  0.009694
# 5983  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-202...  0.203500  0.009998
# 5984  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-184...  0.202990  0.009998
# 5985  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-952...  0.202640  0.009998
# 5986  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-946...  0.202234  0.009998
# 5987  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-119...  0.201772  0.009998
# 5988  AC20171011_Broad_HLA_A1101_R1_Rep01-4024-ALARA...  0.200960  0.009998
# 5989  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-380...  0.199726  0.009998
# 5990  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-118...  0.199647  0.009998
# 5991  AC20171011_Broad_HLA_A1101_R2_Rep01-3549-YVAST...  0.199615  0.009998
# 5992  AC20171011_Broad_HLA_A1101_R1_Rep02-14430-QSVN...  0.199352  0.009998
# 5993  AC20171011_Broad_HLA_A1101_R1_Rep02-8799-LFLRT...  0.199272  0.009998
# 5994  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-120...  0.198134  0.009998
# 5995  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-256...  0.198102  0.009998
# 5996  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-102...  0.197624  0.009998
# 5997  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-173...  0.197569  0.009998
# 5998  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-103...  0.197401  0.009998
# 5999  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-962...  0.197330  0.009998
# 6000  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-174...  0.196884  0.009998
#
#       posterior_error_prob                          peptide  \
# 5981              0.130729                    _.ALTIHAIGR._
# 5982              0.130744                      _.PSTPIAH._
# 5983              0.130892                      _.PALRQLL._
# 5984              0.131392  _.LWC[UNIMOD:4]SRC[UNIMOD:4]F._
# 5985              0.131736                      _.VFEHIGK._
# 5986              0.132136           _.MVAAC[UNIMOD:4]RSV._
# 5987              0.132593                     _.VGEVIVTK._
# 5988              0.133398                    _.ALARALIRK._
# 5989              0.134629                  _.STQAEGTRTLK._
# 5990              0.134709                      _.VMEHFIK._
# 5991              0.134741                    _.YVASTKYQK._
# 5992              0.135004                    _.QSVNMLPLK._
# 5993              0.135084                      _.LFLRTPK._
# 5994              0.136231                  _.RSFAGNLNTYK._
# 5995              0.136264                    _.AIIAILTPK._
# 5996              0.136747                    _.SSPQAGSSL._
# 5997              0.136804                _.TVFYPSDGVATEK._
# 5998              0.136973                   _.SVISRPIVQK._
# 5999              0.137046                     _.IDGSVNPK._
# 6000              0.137500                  _.ASYPGASVDNY._
#
#                        proteinIds   modi_peptide
# 5981                    ALTIHAIGR      ALTIHAIGR
# 5982                      PSTPIAH        PSTPIAH
# 5983                      PALRQLL        PALRQLL
# 5984  LWC[UNIMOD:4]SRC[UNIMOD:4]F        LWCSRCF
# 5985                      VFEHIGK        VFEHIGK
# 5986           MVAAC[UNIMOD:4]RSV       MVAACRSV
# 5987                     VGEVIVTK       VGEVIVTK
# 5988                    ALARALIRK      ALARALIRK
# 5989                  STQAEGTRTLK    STQAEGTRTLK
# 5990                      VMEHFIK        VMEHFIK
# 5991                    YVASTKYQK      YVASTKYQK
# 5992                    QSVNMLPLK      QSVNMLPLK
# 5993                      LFLRTPK        LFLRTPK
# 5994                  RSFAGNLNTYK    RSFAGNLNTYK
# 5995                    AIIAILTPK      AIIAILTPK
# 5996                    SSPQAGSSL      SSPQAGSSL
# 5997                TVFYPSDGVATEK  TVFYPSDGVATEK
# 5998                   SVISRPIVQK     SVISRPIVQK
# 5999                     IDGSVNPK       IDGSVNPK
# 6000                  ASYPGASVDNY    ASYPGASVDNY

# %%
filtered_peptide_A1101.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_peptides_A1101.csv')

# %% [markdown]
# ## 2. resocre target psm

# %%
rescore_psm_A1101 = pandas.read_csv("/home/thinkpad/HLA_Files/A1101/A1101_Oktoberfest_MSFragger/results/percolator/rescore_target.psms", sep= '\t')

# %%
rescore_psm_A1101
# Out:
#                                                    PSMId    score   q-value  \
# 0      AC20171011_Broad_HLA_A1101_R1_Rep02-3085-RVYDP...  2.05516  0.000171
# 1      YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-121...  1.97562  0.000171
# 2      AC20171011_Broad_HLA_A1101_R1_Rep01-3121-RVYDP...  1.94197  0.000171
# 3      AC20171011_Broad_HLA_A1101_R2_Rep02-3055-RVYDP...  1.93092  0.000171
# 4      AC20171011_Broad_HLA_A1101_R1_Rep02-6653-ISDPT...  1.83280  0.000171
# ...                                                  ...      ...       ...
# 60652  AC20171011_Broad_HLA_A1101_R2_Rep01-31936-NKIT... -3.34596  0.249448
# 60653  AC20171011_Broad_HLA_A1101_R1_Rep01-33038-NKIT... -3.38284  0.249448
# 60654  AC20171011_Broad_HLA_A1101_R2_Rep01-26832-ILMG... -3.42819  0.249489
# 60655  AC20171011_Broad_HLA_A1101_R2_Rep01-28172-TQEA... -3.45047  0.249489
# 60656  AC20171011_Broad_HLA_A1101_R1_Rep02-25756-LGTG... -5.07269  0.249567
#
#        posterior_error_prob              peptide       proteinIds
# 0              6.901180e-08      _.RVYDPASPQRR._      RVYDPASPQRR
# 1              1.151810e-07      _.ISDPTSPLRTR._      ISDPTSPLRTR
# 2              1.430560e-07      _.RVYDPASPQRR._      RVYDPASPQRR
# 3              1.536090e-07      _.RVYDPASPQRR._      RVYDPASPQRR
# 4              2.889660e-07      _.ISDPTSPLRTR._      ISDPTSPLRTR
# ...                     ...                  ...              ...
# 60652          1.000000e+00         _.NKITELPK._         NKITELPK
# 60653          1.000000e+00         _.NKITELPK._         NKITELPK
# 60654          1.000000e+00    _.ILMGSTLRKRKMY._    ILMGSTLRKRKMY
# 60655          1.000000e+00    _.TQEALSIHGVKEA._    TQEALSIHGVKEA
# 60656          1.000000e+00  _.LGTGRGTLRLRSRGP._  LGTGRGTLRLRSRGP
#
# [60657 rows x 6 columns]

# %%
print (rescore_psm_A1101.PSMId.unique ,'\n \n') 
print (rescore_psm_A1101.peptide.unique ,'\n \n')
print (rescore_psm_A1101.proteinIds.unique)
# Out:
# <bound method Series.unique of 0        AC20171011_Broad_HLA_A1101_R1_Rep02-3085-RVYDP...
# 1        YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-121...
# 2        AC20171011_Broad_HLA_A1101_R1_Rep01-3121-RVYDP...
# 3        AC20171011_Broad_HLA_A1101_R2_Rep02-3055-RVYDP...
# 4        AC20171011_Broad_HLA_A1101_R1_Rep02-6653-ISDPT...
#                                ...
# 60652    AC20171011_Broad_HLA_A1101_R2_Rep01-31936-NKIT...
# 60653    AC20171011_Broad_HLA_A1101_R1_Rep01-33038-NKIT...
# 60654    AC20171011_Broad_HLA_A1101_R2_Rep01-26832-ILMG...
# 60655    AC20171011_Broad_HLA_A1101_R2_Rep01-28172-TQEA...
# 60656    AC20171011_Broad_HLA_A1101_R1_Rep02-25756-LGTG...
# Name: PSMId, Length: 60657, dtype: object>
#
#
# <bound method Series.unique of 0            _.RVYDPASPQRR._
# 1            _.ISDPTSPLRTR._
# 2            _.RVYDPASPQRR._
# 3            _.RVYDPASPQRR._
# 4            _.ISDPTSPLRTR._
#                 ...
# 60652           _.NKITELPK._
# 60653           _.NKITELPK._
# 60654      _.ILMGSTLRKRKMY._
# 60655      _.TQEALSIHGVKEA._
# 60656    _.LGTGRGTLRLRSRGP._
# Name: peptide, Length: 60657, dtype: object>
#
#
# <bound method Series.unique of 0            RVYDPASPQRR
# 1            ISDPTSPLRTR
# 2            RVYDPASPQRR
# 3            RVYDPASPQRR
# 4            ISDPTSPLRTR
#               ...
# 60652           NKITELPK
# 60653           NKITELPK
# 60654      ILMGSTLRKRKMY
# 60655      TQEALSIHGVKEA
# 60656    LGTGRGTLRLRSRGP
# Name: proteinIds, Length: 60657, dtype: object>

# %% [markdown]
# ### filter the dataset with FDR = 0.01

# %%
filtered_psm_A1101 = rescore_psm_A1101[rescore_psm_A1101['q-value'] <= 0.01]


# modify the peptide in a new column
filtered_psm_A1101["modi_peptide"] = filtered_psm_A1101['peptide']

filtered_psm_A1101
# Out:
# /tmp/ipykernel_235831/955227310.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_A1101["modi_peptide"] = filtered_psm_A1101['peptide']
#                                                    PSMId     score   q-value  \
# 0      AC20171011_Broad_HLA_A1101_R1_Rep02-3085-RVYDP...  2.055160  0.000171
# 1      YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-121...  1.975620  0.000171
# 2      AC20171011_Broad_HLA_A1101_R1_Rep01-3121-RVYDP...  1.941970  0.000171
# 3      AC20171011_Broad_HLA_A1101_R2_Rep02-3055-RVYDP...  1.930920  0.000171
# 4      AC20171011_Broad_HLA_A1101_R1_Rep02-6653-ISDPT...  1.832800  0.000171
# ...                                                  ...       ...       ...
# 46139  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-899...  0.001919  0.009883
# 46140  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-133...  0.000868  0.009947
# 46141  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-233...  0.000541  0.009947
# 46142  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-816...  0.000470  0.009947
# 46143  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-936...  0.000103  0.009969
#
#        posterior_error_prob          peptide   proteinIds     modi_peptide
# 0              6.901180e-08  _.RVYDPASPQRR._  RVYDPASPQRR  _.RVYDPASPQRR._
# 1              1.151810e-07  _.ISDPTSPLRTR._  ISDPTSPLRTR  _.ISDPTSPLRTR._
# 2              1.430560e-07  _.RVYDPASPQRR._  RVYDPASPQRR  _.RVYDPASPQRR._
# 3              1.536090e-07  _.RVYDPASPQRR._  RVYDPASPQRR  _.RVYDPASPQRR._
# 4              2.889660e-07  _.ISDPTSPLRTR._  ISDPTSPLRTR  _.ISDPTSPLRTR._
# ...                     ...              ...          ...              ...
# 46139          3.816920e-01   _.AVFRGRMSMK._   AVFRGRMSMK   _.AVFRGRMSMK._
# 46140          3.848630e-01    _.GLTVPTSPK._    GLTVPTSPK    _.GLTVPTSPK._
# 46141          3.858470e-01     _.VIPFTIKK._     VIPFTIKK     _.VIPFTIKK._
# 46142          3.860620e-01     _.SISNSYVK._     SISNSYVK     _.SISNSYVK._
# 46143          3.871660e-01    _.TQMGPVAAK._    TQMGPVAAK    _.TQMGPVAAK._
#
# [46144 rows x 7 columns]

# %%
filtered_psm_A1101['modi_peptide'] = filtered_psm_A1101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_psm_A1101['modi_peptide'] = filtered_psm_A1101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_psm_A1101.tail(50)
# Out:
# /tmp/ipykernel_235831/1604622521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_A1101['modi_peptide'] = filtered_psm_A1101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/1604622521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_A1101['modi_peptide'] = filtered_psm_A1101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                    PSMId     score   q-value  \
# 46094  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-101...  0.008718  0.009611
# 46095  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-975...  0.008606  0.009630
# 46096  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-970...  0.008527  0.009630
# 46097  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-218...  0.008248  0.009630
# 46098  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-225...  0.008065  0.009630
# 46099  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-668...  0.007906  0.009630
# 46100  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-570...  0.007635  0.009630
# 46101  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-107...  0.007531  0.009630
# 46102  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-311...  0.007500  0.009630
# 46103  AC20171011_Broad_HLA_A1101_R2_Rep01-11850-ATVI...  0.007444  0.009630
# 46104  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-108...  0.007364  0.009630
# 46105  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-136...  0.007285  0.009630
# 46106  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-149...  0.006990  0.009671
# 46107  AC20171011_Broad_HLA_A1101_R1_Rep02-3555-ASYVA...  0.006974  0.009671
# 46108  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-599...  0.006974  0.009671
# 46109  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-287...  0.006863  0.009671
# 46110  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-371...  0.006632  0.009671
# 46111  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-140...  0.006512  0.009671
# 46112  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-170...  0.006409  0.009671
# 46113  AC20171011_Broad_HLA_A1101_R1_Rep02-9369-FRTPI...  0.006321  0.009671
# 46114  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-134...  0.006274  0.009671
# 46115  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-127...  0.006186  0.009671
# 46116  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-542...  0.006122  0.009671
# 46117  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-869...  0.005565  0.009691
# 46118  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-257...  0.005493  0.009691
# 46119  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-407...  0.005406  0.009691
# 46120  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-102...  0.005366  0.009691
# 46121  AC20171011_Broad_HLA_A1101_R2_Rep01-4520-SLNQA...  0.005278  0.009691
# 46122  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-162...  0.005239  0.009691
# 46123  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-109...  0.005199  0.009691
# 46124  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-368...  0.004817  0.009733
# 46125  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-203...  0.004737  0.009733
# 46126  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-8-R...  0.004697  0.009733
# 46127  AC20171011_Broad_HLA_A1101_R2_Rep02-5178-SVDKI...  0.004522  0.009733
# 46128  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-135...  0.004474  0.009733
# 46129  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-119...  0.004092  0.009733
# 46130  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-592...  0.004036  0.009755
# 46131  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-715...  0.004005  0.009755
# 46132  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-141...  0.003798  0.009776
# 46133  YE_20180517_SK_HLA_A1101_3IPs_a50mio_R1_01-307...  0.003654  0.009797
# 46134  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-559...  0.003193  0.009797
# 46135  AC20171011_Broad_HLA_A1101_R2_Rep01-8245-AQNSV...  0.003169  0.009797
# 46136  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-132...  0.003153  0.009797
# 46137  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R1_02-240...  0.002532  0.009797
# 46138  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-122...  0.002038  0.009862
# 46139  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-899...  0.001919  0.009883
# 46140  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-133...  0.000868  0.009947
# 46141  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-233...  0.000541  0.009947
# 46142  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_02-816...  0.000470  0.009947
# 46143  YE_20180517_SK_HLA_A1101_3Ips_a50mio_R2_01-936...  0.000103  0.009969
#
#        posterior_error_prob                   peptide            proteinIds  \
# 46094              0.361068           _.STIVNRGITPK._           STIVNRGITPK
# 46095              0.361408            _.RTYVGSMPGR._            RTYVGSMPGR
# 46096              0.361650            _.ISGPPLKAGK._            ISGPPLKAGK
# 46097              0.362498             _.SAPVGVTAL._             SAPVGVTAL
# 46098              0.363055            _.SIAVKSIHRK._            SIAVKSIHRK
# 46099              0.363540  _.VVM[UNIMOD:35]RDPQTK._  VVM[UNIMOD:35]RDPQTK
# 46100              0.364363             _.STGPITKPK._             STGPITKPK
# 46101              0.364678             _.EGSPPKEEK._             EGSPPKEEK
# 46102              0.364775             _.NAPWAVTSL._             NAPWAVTSL
# 46103              0.364944            _.ATVIFVASQK._            ATVIFVASQK
# 46104              0.365186            _.TVYRNPESFK._            TVYRNPESFK
# 46105              0.365429            _.ATQVAVSVPK._            ATQVAVSVPK
# 46106              0.366324             _.SIFRTPISK._             SIFRTPISK
# 46107              0.366372           _.ASYVASTKYQK._           ASYVASTKYQK
# 46108              0.366372  _.GSM[UNIMOD:35]GSFSEK._  GSM[UNIMOD:35]GSFSEK
# 46109              0.366711          _.ATMETMNIFLEK._          ATMETMNIFLEK
# 46110              0.367413            _.SIAVKSIHRK._            SIAVKSIHRK
# 46111              0.367776            _.NELAAAAVTD._            NELAAAAVTD
# 46112              0.368090              _.LNLEQVEK._              LNLEQVEK
# 46113              0.368356               _.FRTPISK._               FRTPISK
# 46114              0.368501             _.KTLQDIVYK._             KTLQDIVYK
# 46115              0.368767   _.C[UNIMOD:4]IVNMFHTR._   C[UNIMOD:4]IVNMFHTR
# 46116              0.368960             _.GTGKTTFVK._             GTGKTTFVK
# 46117              0.370652             _.RESASAKIK._             RESASAKIK
# 46118              0.370870              _.IGGIFAFK._              IGGIFAFK
# 46119              0.371135  _.VVM[UNIMOD:35]RDPASK._  VVM[UNIMOD:35]RDPASK
# 46120              0.371256           _.VALKAGWQQRK._           VALKAGWQQRK
# 46121              0.371522             _.SLNQAVVSK._             SLNQAVVSK
# 46122              0.371643               _.LDFVKQK._               LDFVKQK
# 46123              0.371763           _.VALKAGWQQRK._           VALKAGWQQRK
# 46124              0.372922             _.KVIVTGASK._             KVIVTGASK
# 46125              0.373164          _.SVIGSNGYILNK._          SVIGSNGYILNK
# 46126              0.373284             _.RVTYPAKAK._             RVTYPAKAK
# 46127              0.373815             _.SVDKIVIQK._             SVDKIVIQK
# 46128              0.373960             _.TTFSPSISK._             TTFSPSISK
# 46129              0.375118           _.AVSKDIANWQK._           AVSKDIANWQK
# 46130              0.375287            _.RTYDREGFKK._            RTYDREGFKK
# 46131              0.375383             _.GTGKTTFVK._             GTGKTTFVK
# 46132              0.376010           _.SISDNSSVSPV._           SISDNSSVSPV
# 46133              0.376444              _.GFLQLVRL._              GFLQLVRL
# 46134              0.377841             _.GVVRIYHRK._             GVVRIYHRK
# 46135              0.377914            _.AQNSVIIVDK._            AQNSVIIVDK
# 46136              0.377962   _.GITETVLC[UNIMOD:4]R._   GITETVLC[UNIMOD:4]R
# 46137              0.379840        _.FAIQDISVEETSAK._        FAIQDISVEETSAK
# 46138              0.381331               _.NPYILKK._               NPYILKK
# 46139              0.381692            _.AVFRGRMSMK._            AVFRGRMSMK
# 46140              0.384863             _.GLTVPTSPK._             GLTVPTSPK
# 46141              0.385847              _.VIPFTIKK._              VIPFTIKK
# 46142              0.386062              _.SISNSYVK._              SISNSYVK
# 46143              0.387166             _.TQMGPVAAK._             TQMGPVAAK
#
#          modi_peptide
# 46094     STIVNRGITPK
# 46095      RTYVGSMPGR
# 46096      ISGPPLKAGK
# 46097       SAPVGVTAL
# 46098      SIAVKSIHRK
# 46099       VVMRDPQTK
# 46100       STGPITKPK
# 46101       EGSPPKEEK
# 46102       NAPWAVTSL
# 46103      ATVIFVASQK
# 46104      TVYRNPESFK
# 46105      ATQVAVSVPK
# 46106       SIFRTPISK
# 46107     ASYVASTKYQK
# 46108       GSMGSFSEK
# 46109    ATMETMNIFLEK
# 46110      SIAVKSIHRK
# 46111      NELAAAAVTD
# 46112        LNLEQVEK
# 46113         FRTPISK
# 46114       KTLQDIVYK
# 46115       CIVNMFHTR
# 46116       GTGKTTFVK
# 46117       RESASAKIK
# 46118        IGGIFAFK
# 46119       VVMRDPASK
# 46120     VALKAGWQQRK
# 46121       SLNQAVVSK
# 46122         LDFVKQK
# 46123     VALKAGWQQRK
# 46124       KVIVTGASK
# 46125    SVIGSNGYILNK
# 46126       RVTYPAKAK
# 46127       SVDKIVIQK
# 46128       TTFSPSISK
# 46129     AVSKDIANWQK
# 46130      RTYDREGFKK
# 46131       GTGKTTFVK
# 46132     SISDNSSVSPV
# 46133        GFLQLVRL
# 46134       GVVRIYHRK
# 46135      AQNSVIIVDK
# 46136       GITETVLCR
# 46137  FAIQDISVEETSAK
# 46138         NPYILKK
# 46139      AVFRGRMSMK
# 46140       GLTVPTSPK
# 46141        VIPFTIKK
# 46142        SISNSYVK
# 46143       TQMGPVAAK

# %%
filtered_psm_A1101.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_psm_A1101.csv')

# %% [markdown]
# # 2. A3101

# %% [markdown]
# ### target peptides

# %%
rescore_peptides_A3101 = pandas.read_csv("/home/thinkpad/HLA_Files/A3101/A3101_Oktoberfest_MSFragger/results/percolator/rescore_target.peptides", sep= '\t')
rescore_peptides_A3101
# Out:
#                                                   PSMId    score   q-value  \
# 0     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.51353  0.001193
# 1     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.44288  0.001193
# 2     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.41419  0.001193
# 3     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.41068  0.001193
# 4     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.37459  0.001193
# ...                                                 ...      ...       ...
# 5136  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_... -3.66139  0.407436
# 5137  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-... -3.71882  0.407746
# 5138  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_... -3.86358  0.408056
# 5139  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_... -4.59373  0.408092
# 5140  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_... -4.74966  0.408092
#
#       posterior_error_prob                        peptide  \
# 0                 0.000005            _.HYNGEAYEDDEHHPR._
# 1                 0.000009              _.LAQHITYVHQHSR._
# 2                 0.000012              _.GFIYVHKPPVHIR._
# 3                 0.000012              _.VDNDENEHQLSLR._
# 4                 0.000016             _.SALDFLHNKGIAHR._
# ...                    ...                            ...
# 5136              1.000000              _.GPAPRRTAPPPPG._
# 5137              1.000000            _.GRDRKADEDSIRKQQ._
# 5138              1.000000            _.QPKTMGHQSASRRRP._
# 5139              1.000000  _.GVHPPAPGM[UNIMOD:35]HPQAP._
# 5140              1.000000                _.SPPAAPRRRHG._
#
#                      proteinIds
# 0               HYNGEAYEDDEHHPR
# 1                 LAQHITYVHQHSR
# 2                 GFIYVHKPPVHIR
# 3                 VDNDENEHQLSLR
# 4                SALDFLHNKGIAHR
# ...                         ...
# 5136              GPAPRRTAPPPPG
# 5137            GRDRKADEDSIRKQQ
# 5138            QPKTMGHQSASRRRP
# 5139  GVHPPAPGM[UNIMOD:35]HPQAP
# 5140                SPPAAPRRRHG
#
# [5141 rows x 6 columns]

# %% [markdown]
# ### filter the dataset with FDR = 0.01

# %%
filtered_peptide_A3101 = rescore_peptides_A3101 [rescore_peptides_A3101['q-value'] <= 0.01]

#modify the peptide in a new column
filtered_peptide_A3101["modi_peptide"] = filtered_peptide_A3101['peptide']
filtered_peptide_A3101
# Out:
# /tmp/ipykernel_235831/657751615.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_A3101["modi_peptide"] = filtered_peptide_A3101['peptide']
#                                                   PSMId     score   q-value  \
# 0     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.513530  0.001193
# 1     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.442880  0.001193
# 2     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.414190  0.001193
# 3     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.410680  0.001193
# 4     C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.374590  0.001193
# ...                                                 ...       ...       ...
# 3066  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_...  0.132015  0.009769
# 3067  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  0.131805  0.009769
# 3068  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  0.129340  0.009769
# 3069  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  0.128763  0.009769
# 3070  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  0.128396  0.009769
#
#       posterior_error_prob                   peptide            proteinIds  \
# 0                 0.000005       _.HYNGEAYEDDEHHPR._       HYNGEAYEDDEHHPR
# 1                 0.000009         _.LAQHITYVHQHSR._         LAQHITYVHQHSR
# 2                 0.000012         _.GFIYVHKPPVHIR._         GFIYVHKPPVHIR
# 3                 0.000012         _.VDNDENEHQLSLR._         VDNDENEHQLSLR
# 4                 0.000016        _.SALDFLHNKGIAHR._        SALDFLHNKGIAHR
# ...                    ...                       ...                   ...
# 3066              0.163514             _.ALFGANANR._             ALFGANANR
# 3067              0.163727  _.M[UNIMOD:35]GLFNFRPS._  M[UNIMOD:35]GLFNFRPS
# 3068              0.166245               _.EHYVDLK._               EHYVDLK
# 3069              0.166839            _.KVKVVVGVAR._            KVKVVVGVAR
# 3070              0.167218             _.LLRIPRPLR._             LLRIPRPLR
#
#                   modi_peptide
# 0          _.HYNGEAYEDDEHHPR._
# 1            _.LAQHITYVHQHSR._
# 2            _.GFIYVHKPPVHIR._
# 3            _.VDNDENEHQLSLR._
# 4           _.SALDFLHNKGIAHR._
# ...                        ...
# 3066             _.ALFGANANR._
# 3067  _.M[UNIMOD:35]GLFNFRPS._
# 3068               _.EHYVDLK._
# 3069            _.KVKVVVGVAR._
# 3070             _.LLRIPRPLR._
#
# [3071 rows x 7 columns]

# %%
filtered_peptide_A3101['modi_peptide'] = filtered_peptide_A3101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_peptide_A3101['modi_peptide'] = filtered_peptide_A3101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_peptide_A3101.head(20)
# Out:
# /tmp/ipykernel_235831/699745520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_A3101['modi_peptide'] = filtered_peptide_A3101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/699745520.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_A3101['modi_peptide'] = filtered_peptide_A3101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                 PSMId    score   q-value  \
# 0   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.51353  0.001193
# 1   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.44288  0.001193
# 2   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.41419  0.001193
# 3   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.41068  0.001193
# 4   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.37459  0.001193
# 5   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.33793  0.001193
# 6   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.33452  0.001193
# 7   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.32561  0.001193
# 8   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.32262  0.001193
# 9   C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.31087  0.001193
# 10  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.30751  0.001193
# 11  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.29796  0.001193
# 12  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.29403  0.001193
# 13  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  1.28234  0.001193
# 14  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  1.27552  0.001193
# 15  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  1.27546  0.001193
# 16  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  1.27022  0.001193
# 17  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  1.25443  0.001193
# 18  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.25443  0.001193
# 19  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.23927  0.001193
#
#     posterior_error_prob                               peptide  \
# 0               0.000005                   _.HYNGEAYEDDEHHPR._
# 1               0.000009                     _.LAQHITYVHQHSR._
# 2               0.000012                     _.GFIYVHKPPVHIR._
# 3               0.000012                     _.VDNDENEHQLSLR._
# 4               0.000016                    _.SALDFLHNKGIAHR._
# 5               0.000021                    _.HQAFEAELHANADR._
# 6               0.000021                   _.HLEINPDHPIVETLR._
# 7               0.000023                    _.YFQFQEEGKEGENR._
# 8               0.000023                    _.SYISVYDHQGIFKR._
# 9               0.000025                    _.APGTPHSHTKPYVR._
# 10              0.000026                    _.AAEDDEDDDVDTKK._
# 11              0.000028  _.LFQEC[UNIMOD:4]C[UNIMOD:4]PHSTDR._
# 12              0.000029                   _.EQLEEEEEAKHNLEK._
# 13              0.000031          _.HELQANC[UNIMOD:4]YEEVKDR._
# 14              0.000033                    _.QEYDESGPSIVHRK._
# 15              0.000033                    _.AVQHFSLLYKTVQR._
# 16              0.000034                   _.HLEINPDHSIIETLR._
# 17              0.000039                      _.DSYVGDEAQSKR._
# 18              0.000039                    _.QIILEKEETEELKR._
# 19              0.000043                     _.GYFEYIEENKYSR._
#
#                           proteinIds     modi_peptide
# 0                    HYNGEAYEDDEHHPR  HYNGEAYEDDEHHPR
# 1                      LAQHITYVHQHSR    LAQHITYVHQHSR
# 2                      GFIYVHKPPVHIR    GFIYVHKPPVHIR
# 3                      VDNDENEHQLSLR    VDNDENEHQLSLR
# 4                     SALDFLHNKGIAHR   SALDFLHNKGIAHR
# 5                     HQAFEAELHANADR   HQAFEAELHANADR
# 6                    HLEINPDHPIVETLR  HLEINPDHPIVETLR
# 7                     YFQFQEEGKEGENR   YFQFQEEGKEGENR
# 8                     SYISVYDHQGIFKR   SYISVYDHQGIFKR
# 9                     APGTPHSHTKPYVR   APGTPHSHTKPYVR
# 10                    AAEDDEDDDVDTKK   AAEDDEDDDVDTKK
# 11  LFQEC[UNIMOD:4]C[UNIMOD:4]PHSTDR     LFQECCPHSTDR
# 12                   EQLEEEEEAKHNLEK  EQLEEEEEAKHNLEK
# 13          HELQANC[UNIMOD:4]YEEVKDR   HELQANCYEEVKDR
# 14                    QEYDESGPSIVHRK   QEYDESGPSIVHRK
# 15                    AVQHFSLLYKTVQR   AVQHFSLLYKTVQR
# 16                   HLEINPDHSIIETLR  HLEINPDHSIIETLR
# 17                      DSYVGDEAQSKR     DSYVGDEAQSKR
# 18                    QIILEKEETEELKR   QIILEKEETEELKR
# 19                     GYFEYIEENKYSR    GYFEYIEENKYSR

# %%
filtered_peptide_A3101.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_peptides_A3101.csv')

# %% [markdown]
# ### target psms

# %%
rescore_psm_A3101 = pandas.read_csv("/home/thinkpad/HLA_Files/A3101/A3101_Oktoberfest_MSFragger/results/percolator/rescore_target.psms", sep= '\t')
rescore_psm_A3101
# Out:
#                                                    PSMId    score   q-value  \
# 0      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.51353  0.000366
# 1      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.44288  0.000366
# 2      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.41419  0.000366
# 3      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.41068  0.000366
# 4      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  1.40690  0.000366
# ...                                                  ...      ...       ...
# 13658  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_... -3.66139  0.191229
# 13659  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-... -3.71882  0.191362
# 13660  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_... -3.86358  0.191494
# 13661  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_... -4.59373  0.191539
# 13662  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_... -4.74966  0.191539
#
#        posterior_error_prob                        peptide  \
# 0              1.574590e-07            _.HYNGEAYEDDEHHPR._
# 1              3.142210e-07              _.LAQHITYVHQHSR._
# 2              4.159960e-07              _.GFIYVHKPPVHIR._
# 3              4.305420e-07              _.VDNDENEHQLSLR._
# 4              4.467390e-07              _.VDNDENEHQLSLR._
# ...                     ...                            ...
# 13658          1.000000e+00              _.GPAPRRTAPPPPG._
# 13659          1.000000e+00            _.GRDRKADEDSIRKQQ._
# 13660          1.000000e+00            _.QPKTMGHQSASRRRP._
# 13661          1.000000e+00  _.GVHPPAPGM[UNIMOD:35]HPQAP._
# 13662          1.000000e+00                _.SPPAAPRRRHG._
#
#                       proteinIds
# 0                HYNGEAYEDDEHHPR
# 1                  LAQHITYVHQHSR
# 2                  GFIYVHKPPVHIR
# 3                  VDNDENEHQLSLR
# 4                  VDNDENEHQLSLR
# ...                          ...
# 13658              GPAPRRTAPPPPG
# 13659            GRDRKADEDSIRKQQ
# 13660            QPKTMGHQSASRRRP
# 13661  GVHPPAPGM[UNIMOD:35]HPQAP
# 13662                SPPAAPRRRHG
#
# [13663 rows x 6 columns]

# %% [markdown]
# ## filter the dataset with FDR = 0.01

# %%
filtered_psm_A3101 = rescore_psm_A3101[rescore_psm_A3101['q-value'] <= 0.01]

#modify psms in a new column
filtered_psm_A3101["modi_peptide"] = filtered_psm_A3101['peptide']

filtered_psm_A3101
# Out:
# /tmp/ipykernel_235831/370045065.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_A3101["modi_peptide"] = filtered_psm_A3101['peptide']
#                                                    PSMId     score   q-value  \
# 0      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.513530  0.000366
# 1      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.442880  0.000366
# 2      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.414190  0.000366
# 3      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  1.410680  0.000366
# 4      C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  1.406900  0.000366
# ...                                                  ...       ...       ...
# 11072  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  0.003095  0.009573
# 11073  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.000524  0.009753
# 11074  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_...  0.000472  0.009841
# 11075  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  0.000367  0.009841
# 11076  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.000000  0.009930
#
#        posterior_error_prob              peptide       proteinIds  \
# 0              1.574590e-07  _.HYNGEAYEDDEHHPR._  HYNGEAYEDDEHHPR
# 1              3.142210e-07    _.LAQHITYVHQHSR._    LAQHITYVHQHSR
# 2              4.159960e-07    _.GFIYVHKPPVHIR._    GFIYVHKPPVHIR
# 3              4.305420e-07    _.VDNDENEHQLSLR._    VDNDENEHQLSLR
# 4              4.467390e-07    _.VDNDENEHQLSLR._    VDNDENEHQLSLR
# ...                     ...                  ...              ...
# 11072          2.473170e-01      _.AVKVHSFPTLK._      AVKVHSFPTLK
# 11073          2.513860e-01         _.YDRQGIGR._         YDRQGIGR
# 11074          2.514690e-01         _.KVWVPKQK._         KVWVPKQK
# 11075          2.516360e-01         _.FLRPHYGK._         FLRPHYGK
# 11076          2.522210e-01        _.DFRPKAYLR._        DFRPKAYLR
#
#               modi_peptide
# 0      _.HYNGEAYEDDEHHPR._
# 1        _.LAQHITYVHQHSR._
# 2        _.GFIYVHKPPVHIR._
# 3        _.VDNDENEHQLSLR._
# 4        _.VDNDENEHQLSLR._
# ...                    ...
# 11072      _.AVKVHSFPTLK._
# 11073         _.YDRQGIGR._
# 11074         _.KVWVPKQK._
# 11075         _.FLRPHYGK._
# 11076        _.DFRPKAYLR._
#
# [11077 rows x 7 columns]

# %%
filtered_psm_A3101['modi_peptide'] = filtered_psm_A3101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_psm_A3101['modi_peptide'] = filtered_psm_A3101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_psm_A3101.tail(20)
# Out:
# /tmp/ipykernel_235831/3978721824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_A3101['modi_peptide'] = filtered_psm_A3101['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/3978721824.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_A3101['modi_peptide'] = filtered_psm_A3101['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                    PSMId     score   q-value  \
# 11057  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  0.018987  0.008952
# 11058  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  0.017728  0.008952
# 11059  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.015000  0.009129
# 11060  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.014581  0.009129
# 11061  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.014319  0.009129
# 11062  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.014214  0.009129
# 11063  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_...  0.013637  0.009129
# 11064  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.012640  0.009217
# 11065  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_...  0.011381  0.009217
# 11066  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_...  0.009336  0.009397
# 11067  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.007867  0.009483
# 11068  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  0.007448  0.009483
# 11069  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  0.006976  0.009483
# 11070  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.005665  0.009483
# 11071  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  0.004143  0.009483
# 11072  M20150626_JGA_HLA_A31_biorep2_5e7ceq_reinject_...  0.003095  0.009573
# 11073  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.000524  0.009753
# 11074  M20150626_JGA_HLA_A31_biorep1_5e7ceq_reinject_...  0.000472  0.009841
# 11075  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep1-...  0.000367  0.009841
# 11076  C20150427_JGA_3uLof6uL_1e8ceq_HLA_A31_IP_rep2-...  0.000000  0.009930
#
#        posterior_error_prob                     peptide  \
# 11057              0.223092           _.KSLEDVVRAYLKM._
# 11058              0.224952                 _.NVPNWHR._
# 11059              0.229017               _.KLYPWIHQF._
# 11060              0.229646               _.NVEIDPEIQ._
# 11061              0.230040           _.GNRLGNAGLLALA._
# 11062              0.230198  _.ATM[UNIMOD:35]VPSVLWPR._
# 11063              0.231067              _.EIIQAQLVNR._
# 11064              0.232573               _.SNSPVLLSR._
# 11065              0.234484               _.ATVRELAPR._
# 11066              0.237611              _.KSLDQAISRF._
# 11067              0.239872               _.SNSPVLLSR._
# 11068              0.240521               _.ATVRELAPR._
# 11069              0.241252   _.SIPKM[UNIMOD:35]CSQLR._
# 11070              0.243291               _.RDPNNYRPR._
# 11071              0.245669                _.KVWVPKQK._
# 11072              0.247317             _.AVKVHSFPTLK._
# 11073              0.251386                _.YDRQGIGR._
# 11074              0.251469                _.KVWVPKQK._
# 11075              0.251636                _.FLRPHYGK._
# 11076              0.252221               _.DFRPKAYLR._
#
#                    proteinIds   modi_peptide
# 11057           KSLEDVVRAYLKM  KSLEDVVRAYLKM
# 11058                 NVPNWHR        NVPNWHR
# 11059               KLYPWIHQF      KLYPWIHQF
# 11060               NVEIDPEIQ      NVEIDPEIQ
# 11061           GNRLGNAGLLALA  GNRLGNAGLLALA
# 11062  ATM[UNIMOD:35]VPSVLWPR    ATMVPSVLWPR
# 11063              EIIQAQLVNR     EIIQAQLVNR
# 11064               SNSPVLLSR      SNSPVLLSR
# 11065               ATVRELAPR      ATVRELAPR
# 11066              KSLDQAISRF     KSLDQAISRF
# 11067               SNSPVLLSR      SNSPVLLSR
# 11068               ATVRELAPR      ATVRELAPR
# 11069   SIPKM[UNIMOD:35]CSQLR     SIPKMCSQLR
# 11070               RDPNNYRPR      RDPNNYRPR
# 11071                KVWVPKQK       KVWVPKQK
# 11072             AVKVHSFPTLK    AVKVHSFPTLK
# 11073                YDRQGIGR       YDRQGIGR
# 11074                KVWVPKQK       KVWVPKQK
# 11075                FLRPHYGK       FLRPHYGK
# 11076               DFRPKAYLR      DFRPKAYLR

# %%
filtered_psm_A3101.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_psm_A3101.csv')

# %% [markdown]
# # 3. C1203

# %% [markdown]
# ### target peptides

# %%
rescore_peptides_C1203 = pandas.read_csv("//home/thinkpad/HLA_Files/C1203/C1203_Oktoberfest_MSFragger/results/percolator/rescore_target.peptides", sep= '\t')
rescore_peptides_C1203
# Out:
#                                                   PSMId    score   q-value  \
# 0     GG20170112_CRH_HLA_C1203_biorep1_techrep2-7563...  1.25617  0.000767
# 1     GG20170112_CRH_HLA_C1203_biorep2_techrep1-5595...  1.22187  0.000767
# 2     GG20170112_CRH_HLA_C1203_biorep2_techrep1-6091...  1.08576  0.000767
# 3     GG20170112_CRH_HLA_C1203_biorep1_techrep2-1912...  1.04370  0.000767
# 4     GG20170112_CRH_HLA_C1203_biorep1_techrep2-4771...  1.03313  0.000767
# ...                                                 ...      ...       ...
# 8523  GG20170112_CRH_HLA_C1203_biorep2_techrep2-5042... -3.18630  0.603800
# 8524  GG20170112_CRH_HLA_C1203_biorep2_techrep2-3582... -3.19879  0.603800
# 8525  GG20170112_CRH_HLA_C1203_biorep1_techrep2-4038... -3.21059  0.603800
# 8526  GG20170112_CRH_HLA_C1203_biorep2_techrep1-4058... -3.47563  0.604245
# 8527  GG20170112_CRH_HLA_C1203_biorep2_techrep2-3933... -3.48113  0.604245
#
#       posterior_error_prob                        peptide  \
# 0                 0.000006            _.HSQGLGGHYADSYLK._
# 1                 0.000008     _.ESGPSIVHRKC[UNIMOD:4]F._
# 2                 0.000027        _.YSFGGC[UNIMOD:4]HRY._
# 3                 0.000039            _.HQGLPQEVLNENLLR._
# 4                 0.000043                  _.KTFPYQHRY._
# ...                    ...                            ...
# 8523              1.000000              _.KKHMQTHKVWPPG._
# 8524              1.000000  _.KPGTM[UNIMOD:35]AAGGGGPAP._
# 8525              1.000000            _.KSRYRSKPRHRRGNS._
# 8526              1.000000              _.KKRLKISKKPKDP._
# 8527              1.000000               _.AAPKQPVGGGQK._
#
#                      proteinIds
# 0               HSQGLGGHYADSYLK
# 1        ESGPSIVHRKC[UNIMOD:4]F
# 2           YSFGGC[UNIMOD:4]HRY
# 3               HQGLPQEVLNENLLR
# 4                     KTFPYQHRY
# ...                         ...
# 8523              KKHMQTHKVWPPG
# 8524  KPGTM[UNIMOD:35]AAGGGGPAP
# 8525            KSRYRSKPRHRRGNS
# 8526              KKRLKISKKPKDP
# 8527               AAPKQPVGGGQK
#
# [8528 rows x 6 columns]

# %% [markdown]
# ### filter the dataset with FDR = 0.01

# %%
filtered_peptide_C1203 = rescore_peptides_C1203[rescore_peptides_C1203['q-value'] <= 0.01]

#modify the peptide in a new column
filtered_peptide_C1203["modi_peptide"] = filtered_peptide_C1203['peptide']

filtered_peptide_C1203
# Out:
# /tmp/ipykernel_235831/3638966581.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_C1203["modi_peptide"] = filtered_peptide_C1203['peptide']
#                                                   PSMId     score   q-value  \
# 0     GG20170112_CRH_HLA_C1203_biorep1_techrep2-7563...  1.256170  0.000767
# 1     GG20170112_CRH_HLA_C1203_biorep2_techrep1-5595...  1.221870  0.000767
# 2     GG20170112_CRH_HLA_C1203_biorep2_techrep1-6091...  1.085760  0.000767
# 3     GG20170112_CRH_HLA_C1203_biorep1_techrep2-1912...  1.043700  0.000767
# 4     GG20170112_CRH_HLA_C1203_biorep1_techrep2-4771...  1.033130  0.000767
# ...                                                 ...       ...       ...
# 3188  GG20170112_CRH_HLA_C1203_biorep2_techrep1-5489...  0.139536  0.009709
# 3189  GG20170112_CRH_HLA_C1203_biorep1_techrep2-6681...  0.139491  0.009709
# 3190  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2886...  0.138029  0.009709
# 3191  GG20170112_CRH_HLA_C1203_biorep2_techrep2-2215...  0.137778  0.009709
# 3192  GG20170112_CRH_HLA_C1203_biorep1_techrep2-4136...  0.136819  0.009709
#
#       posterior_error_prob                     peptide  \
# 0                 0.000006         _.HSQGLGGHYADSYLK._
# 1                 0.000008  _.ESGPSIVHRKC[UNIMOD:4]F._
# 2                 0.000027     _.YSFGGC[UNIMOD:4]HRY._
# 3                 0.000039         _.HQGLPQEVLNENLLR._
# 4                 0.000043               _.KTFPYQHRY._
# ...                    ...                         ...
# 3188              0.112369              _.AGFAGDDAPR._
# 3189              0.112409              _.ALVYGEATSR._
# 3190              0.113694               _.VGFEEVIVV._
# 3191              0.113916               _.STLGHMVLF._
# 3192              0.114768              _.FVAPFPLSIW._
#
#                   proteinIds                modi_peptide
# 0            HSQGLGGHYADSYLK         _.HSQGLGGHYADSYLK._
# 1     ESGPSIVHRKC[UNIMOD:4]F  _.ESGPSIVHRKC[UNIMOD:4]F._
# 2        YSFGGC[UNIMOD:4]HRY     _.YSFGGC[UNIMOD:4]HRY._
# 3            HQGLPQEVLNENLLR         _.HQGLPQEVLNENLLR._
# 4                  KTFPYQHRY               _.KTFPYQHRY._
# ...                      ...                         ...
# 3188              AGFAGDDAPR              _.AGFAGDDAPR._
# 3189              ALVYGEATSR              _.ALVYGEATSR._
# 3190               VGFEEVIVV               _.VGFEEVIVV._
# 3191               STLGHMVLF               _.STLGHMVLF._
# 3192              FVAPFPLSIW              _.FVAPFPLSIW._
#
# [3193 rows x 7 columns]

# %%
filtered_peptide_C1203['modi_peptide'] = filtered_peptide_C1203['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_peptide_C1203['modi_peptide'] = filtered_peptide_C1203['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_peptide_C1203.tail(20)
# Out:
# /tmp/ipykernel_235831/3691960612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_C1203['modi_peptide'] = filtered_peptide_C1203['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/3691960612.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_C1203['modi_peptide'] = filtered_peptide_C1203['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                   PSMId     score   q-value  \
# 3173  GG20170112_CRH_HLA_C1203_biorep2_techrep2-1038...  0.144446  0.009709
# 3174  GG20170112_CRH_HLA_C1203_biorep2_techrep2-2756...  0.144332  0.009709
# 3175  GG20170112_CRH_HLA_C1203_biorep2_techrep2-1555...  0.143943  0.009709
# 3176  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2953...  0.143921  0.009709
# 3177  GG20170112_CRH_HLA_C1203_biorep2_techrep2-2533...  0.143829  0.009709
# 3178  GG20170112_CRH_HLA_C1203_biorep2_techrep2-1284...  0.143395  0.009709
# 3179  GG20170112_CRH_HLA_C1203_biorep1_techrep2-4735...  0.143258  0.009709
# 3180  GG20170112_CRH_HLA_C1203_biorep2_techrep1-2707...  0.142756  0.009709
# 3181  GG20170112_CRH_HLA_C1203_biorep1_techrep2-3588...  0.142642  0.009709
# 3182  GG20170112_CRH_HLA_C1203_biorep2_techrep1-1690...  0.141957  0.009709
# 3183  GG20170112_CRH_HLA_C1203_biorep1_techrep2-1362...  0.141523  0.009709
# 3184  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2388...  0.141409  0.009709
# 3185  GG20170112_CRH_HLA_C1203_biorep2_techrep1-2127...  0.140792  0.009709
# 3186  GG20170112_CRH_HLA_C1203_biorep1_techrep2-3720...  0.139925  0.009709
# 3187  GG20170112_CRH_HLA_C1203_biorep2_techrep1-1805...  0.139765  0.009709
# 3188  GG20170112_CRH_HLA_C1203_biorep2_techrep1-5489...  0.139536  0.009709
# 3189  GG20170112_CRH_HLA_C1203_biorep1_techrep2-6681...  0.139491  0.009709
# 3190  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2886...  0.138029  0.009709
# 3191  GG20170112_CRH_HLA_C1203_biorep2_techrep2-2215...  0.137778  0.009709
# 3192  GG20170112_CRH_HLA_C1203_biorep1_techrep2-4136...  0.136819  0.009709
#
#       posterior_error_prob                              peptide  \
# 3173              0.108142                        _.QAYKAPVVV._
# 3174              0.108239                        _.VSFQEVVTF._
# 3175              0.108568                        _.LAYSGVHLY._
# 3176              0.108588                        _.RFVIFPIEY._
# 3177              0.108665                        _.LASAVISVL._
# 3178              0.109035                        _.YAFDFARQS._
# 3179              0.109152                        _.SIPEKNRPL._
# 3180              0.109581                        _.LASGLILIT._
# 3181              0.109679                        _.LASGLVVFF._
# 3182              0.110268                        _.AANGIGAVL._
# 3183              0.110642                        _.SAPYGRITL._
# 3184              0.110740                        _.AIYDVTVVY._
# 3185              0.111274                        _.GARVPWLSV._
# 3186              0.112030                        _.IAAGLYLLL._
# 3187              0.112169  _.LVAM[UNIMOD:35]GALVM[UNIMOD:35]._
# 3188              0.112369                       _.AGFAGDDAPR._
# 3189              0.112409                       _.ALVYGEATSR._
# 3190              0.113694                        _.VGFEEVIVV._
# 3191              0.113916                        _.STLGHMVLF._
# 3192              0.114768                       _.FVAPFPLSIW._
#
#                            proteinIds modi_peptide
# 3173                        QAYKAPVVV    QAYKAPVVV
# 3174                        VSFQEVVTF    VSFQEVVTF
# 3175                        LAYSGVHLY    LAYSGVHLY
# 3176                        RFVIFPIEY    RFVIFPIEY
# 3177                        LASAVISVL    LASAVISVL
# 3178                        YAFDFARQS    YAFDFARQS
# 3179                        SIPEKNRPL    SIPEKNRPL
# 3180                        LASGLILIT    LASGLILIT
# 3181                        LASGLVVFF    LASGLVVFF
# 3182                        AANGIGAVL    AANGIGAVL
# 3183                        SAPYGRITL    SAPYGRITL
# 3184                        AIYDVTVVY    AIYDVTVVY
# 3185                        GARVPWLSV    GARVPWLSV
# 3186                        IAAGLYLLL    IAAGLYLLL
# 3187  LVAM[UNIMOD:35]GALVM[UNIMOD:35]    LVAMGALVM
# 3188                       AGFAGDDAPR   AGFAGDDAPR
# 3189                       ALVYGEATSR   ALVYGEATSR
# 3190                        VGFEEVIVV    VGFEEVIVV
# 3191                        STLGHMVLF    STLGHMVLF
# 3192                       FVAPFPLSIW   FVAPFPLSIW

# %%
filtered_peptide_C1203.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_peptides_C1203.csv')

# %% [markdown]
# ### Target PSMs

# %%
rescore_psm_C1203 = pandas.read_csv("/home/thinkpad/HLA_Files/C1203/C1203_Oktoberfest_MSFragger/results/percolator/rescore_target.psms", sep= '\t')
rescore_psm_C1203
# Out:
#                                                    PSMId    score   q-value  \
# 0      GG20170112_CRH_HLA_C1203_biorep1_techrep2-7563...  1.25617  0.000151
# 1      GG20170112_CRH_HLA_C1203_biorep2_techrep1-5595...  1.22187  0.000151
# 2      GG20170112_CRH_HLA_C1203_biorep2_techrep2-5475...  1.19139  0.000151
# 3      GG20170112_CRH_HLA_C1203_biorep1_techrep2-5524...  1.17358  0.000151
# 4      GG20170112_CRH_HLA_C1203_biorep2_techrep1-7678...  1.14239  0.000151
# ...                                                  ...      ...       ...
# 28113  GG20170112_CRH_HLA_C1203_biorep2_techrep2-5042... -3.18630  0.276035
# 28114  GG20170112_CRH_HLA_C1203_biorep2_techrep2-3582... -3.19879  0.276035
# 28115  GG20170112_CRH_HLA_C1203_biorep1_techrep2-4038... -3.21059  0.276035
# 28116  GG20170112_CRH_HLA_C1203_biorep2_techrep1-4058... -3.47563  0.276229
# 28117  GG20170112_CRH_HLA_C1203_biorep2_techrep2-3933... -3.48113  0.276229
#
#        posterior_error_prob                        peptide  \
# 0              1.775890e-07            _.HSQGLGGHYADSYLK._
# 1              2.535690e-07     _.ESGPSIVHRKC[UNIMOD:4]F._
# 2              3.480000e-07     _.ESGPSIVHRKC[UNIMOD:4]F._
# 3              4.187040e-07     _.ESGPSIVHRKC[UNIMOD:4]F._
# 4              5.788720e-07            _.HSQGLGGHYADSYLK._
# ...                     ...                            ...
# 28113          1.000000e+00              _.KKHMQTHKVWPPG._
# 28114          1.000000e+00  _.KPGTM[UNIMOD:35]AAGGGGPAP._
# 28115          1.000000e+00            _.KSRYRSKPRHRRGNS._
# 28116          1.000000e+00              _.KKRLKISKKPKDP._
# 28117          1.000000e+00               _.AAPKQPVGGGQK._
#
#                       proteinIds
# 0                HSQGLGGHYADSYLK
# 1         ESGPSIVHRKC[UNIMOD:4]F
# 2         ESGPSIVHRKC[UNIMOD:4]F
# 3         ESGPSIVHRKC[UNIMOD:4]F
# 4                HSQGLGGHYADSYLK
# ...                          ...
# 28113              KKHMQTHKVWPPG
# 28114  KPGTM[UNIMOD:35]AAGGGGPAP
# 28115            KSRYRSKPRHRRGNS
# 28116              KKRLKISKKPKDP
# 28117               AAPKQPVGGGQK
#
# [28118 rows x 6 columns]

# %% [markdown]
# ### filter the dataset with FDR = 0.01

# %%
filtered_psm_C1203 = rescore_psm_C1203[rescore_psm_C1203['q-value'] <= 0.01]

# modify the peptide in a new column
filtered_psm_C1203["modi_peptide"] = filtered_psm_C1203['peptide']

filtered_psm_C1203
# Out:
# /tmp/ipykernel_235831/2609514326.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_C1203["modi_peptide"] = filtered_psm_C1203['peptide']
#                                                    PSMId     score   q-value  \
# 0      GG20170112_CRH_HLA_C1203_biorep1_techrep2-7563...  1.256170  0.000151
# 1      GG20170112_CRH_HLA_C1203_biorep2_techrep1-5595...  1.221870  0.000151
# 2      GG20170112_CRH_HLA_C1203_biorep2_techrep2-5475...  1.191390  0.000151
# 3      GG20170112_CRH_HLA_C1203_biorep1_techrep2-5524...  1.173580  0.000151
# 4      GG20170112_CRH_HLA_C1203_biorep2_techrep1-7678...  1.142390  0.000151
# ...                                                  ...       ...       ...
# 20419  GG20170112_CRH_HLA_C1203_biorep2_techrep1-2127...  0.000480  0.009988
# 20420  GG20170112_CRH_HLA_C1203_biorep2_techrep2-1544...  0.000320  0.009988
# 20421  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2706...  0.000274  0.009988
# 20422  GG20170112_CRH_HLA_C1203_biorep1_techrep2-3951...  0.000091  0.009988
# 20423  GG20170112_CRH_HLA_C1203_biorep1_techrep2-3955...  0.000000  0.009988
#
#        posterior_error_prob                     peptide  \
# 0              1.775890e-07         _.HSQGLGGHYADSYLK._
# 1              2.535690e-07  _.ESGPSIVHRKC[UNIMOD:4]F._
# 2              3.480000e-07  _.ESGPSIVHRKC[UNIMOD:4]F._
# 3              4.187040e-07  _.ESGPSIVHRKC[UNIMOD:4]F._
# 4              5.788720e-07         _.HSQGLGGHYADSYLK._
# ...                     ...                         ...
# 20419          2.285720e-01    _.SAAM[UNIMOD:35]VFSAL._
# 20420          2.290250e-01              _.KAFISNLNEM._
# 20421          2.291540e-01               _.HTVGFILQL._
# 20422          2.296720e-01               _.VALPMVLVL._
# 20423          2.299310e-01               _.VALPMVLVL._
#
#                    proteinIds                modi_peptide
# 0             HSQGLGGHYADSYLK         _.HSQGLGGHYADSYLK._
# 1      ESGPSIVHRKC[UNIMOD:4]F  _.ESGPSIVHRKC[UNIMOD:4]F._
# 2      ESGPSIVHRKC[UNIMOD:4]F  _.ESGPSIVHRKC[UNIMOD:4]F._
# 3      ESGPSIVHRKC[UNIMOD:4]F  _.ESGPSIVHRKC[UNIMOD:4]F._
# 4             HSQGLGGHYADSYLK         _.HSQGLGGHYADSYLK._
# ...                       ...                         ...
# 20419    SAAM[UNIMOD:35]VFSAL    _.SAAM[UNIMOD:35]VFSAL._
# 20420              KAFISNLNEM              _.KAFISNLNEM._
# 20421               HTVGFILQL               _.HTVGFILQL._
# 20422               VALPMVLVL               _.VALPMVLVL._
# 20423               VALPMVLVL               _.VALPMVLVL._
#
# [20424 rows x 7 columns]

# %%
filtered_psm_C1203['modi_peptide'] = filtered_psm_C1203['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_psm_C1203['modi_peptide'] = filtered_psm_C1203['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_psm_C1203.tail(20)
# Out:
# /tmp/ipykernel_235831/2809404343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_C1203['modi_peptide'] = filtered_psm_C1203['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/2809404343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_C1203['modi_peptide'] = filtered_psm_C1203['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                    PSMId     score   q-value  \
# 20404  GG20170112_CRH_HLA_C1203_biorep2_techrep2-1077...  0.002809  0.009798
# 20405  GG20170112_CRH_HLA_C1203_biorep2_techrep2-1905...  0.002672  0.009798
# 20406  GG20170112_CRH_HLA_C1203_biorep2_techrep1-1991...  0.002672  0.009798
# 20407  GG20170112_CRH_HLA_C1203_biorep2_techrep2-2984...  0.002603  0.009798
# 20408  GG20170112_CRH_HLA_C1203_biorep1_techrep2-1894...  0.002489  0.009798
# 20409  GG20170112_CRH_HLA_C1203_biorep2_techrep1-7268...  0.002489  0.009798
# 20410  GG20170112_CRH_HLA_C1203_biorep2_techrep1-9208...  0.002489  0.009798
# 20411  GG20170112_CRH_HLA_C1203_biorep1_techrep2-3944...  0.002466  0.009798
# 20412  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2631...  0.001621  0.009895
# 20413  GG20170112_CRH_HLA_C1203_biorep2_techrep1-2779...  0.001461  0.009895
# 20414  GG20170112_CRH_HLA_C1203_biorep2_techrep1-3910...  0.001347  0.009942
# 20415  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2689...  0.001119  0.009942
# 20416  GG20170112_CRH_HLA_C1203_biorep1_techrep2-1243...  0.000868  0.009942
# 20417  GG20170112_CRH_HLA_C1203_biorep1_techrep2-1400...  0.000685  0.009942
# 20418  GG20170112_CRH_HLA_C1203_biorep2_techrep1-2555...  0.000480  0.009988
# 20419  GG20170112_CRH_HLA_C1203_biorep2_techrep1-2127...  0.000480  0.009988
# 20420  GG20170112_CRH_HLA_C1203_biorep2_techrep2-1544...  0.000320  0.009988
# 20421  GG20170112_CRH_HLA_C1203_biorep1_techrep2-2706...  0.000274  0.009988
# 20422  GG20170112_CRH_HLA_C1203_biorep1_techrep2-3951...  0.000091  0.009988
# 20423  GG20170112_CRH_HLA_C1203_biorep1_techrep2-3955...  0.000000  0.009988
#
#        posterior_error_prob                   peptide            proteinIds  \
# 20404              0.222035             _.SAQEKMSIL._             SAQEKMSIL
# 20405              0.222417   _.SAVEVC[UNIMOD:4]VVY._   SAVEVC[UNIMOD:4]VVY
# 20406              0.222417   _.C[UNIMOD:4]ASSLLNQI._   C[UNIMOD:4]ASSLLNQI
# 20407              0.222608  _.LVLM[UNIMOD:35]VGVVM._  LVLM[UNIMOD:35]VGVVM
# 20408              0.222926            _.VAMNPTNTVF._            VAMNPTNTVF
# 20409              0.222926            _.TVTEKPEVID._            TVTEKPEVID
# 20410              0.222926           _.RQIEREHLIQL._           RQIEREHLIQL
# 20411              0.222990             _.VALPMVLVL._             VALPMVLVL
# 20412              0.225354             _.AAFPIAVVA._             AAFPIAVVA
# 20413              0.225803             _.SASPWALTI._             SASPWALTI
# 20414              0.226124             _.FTFGFIQVM._             FTFGFIQVM
# 20415              0.226767              _.AAFPIAVV._              AAFPIAVV
# 20416              0.227475             _.AAAAVAAVV._             AAAAVAAVV
# 20417              0.227991             _.AAFSKYLTA._             AAFSKYLTA
# 20418              0.228572             _.FLANVSTVL._             FLANVSTVL
# 20419              0.228572  _.SAAM[UNIMOD:35]VFSAL._  SAAM[UNIMOD:35]VFSAL
# 20420              0.229025            _.KAFISNLNEM._            KAFISNLNEM
# 20421              0.229154             _.HTVGFILQL._             HTVGFILQL
# 20422              0.229672             _.VALPMVLVL._             VALPMVLVL
# 20423              0.229931             _.VALPMVLVL._             VALPMVLVL
#
#       modi_peptide
# 20404    SAQEKMSIL
# 20405    SAVEVCVVY
# 20406    CASSLLNQI
# 20407    LVLMVGVVM
# 20408   VAMNPTNTVF
# 20409   TVTEKPEVID
# 20410  RQIEREHLIQL
# 20411    VALPMVLVL
# 20412    AAFPIAVVA
# 20413    SASPWALTI
# 20414    FTFGFIQVM
# 20415     AAFPIAVV
# 20416    AAAAVAAVV
# 20417    AAFSKYLTA
# 20418    FLANVSTVL
# 20419    SAAMVFSAL
# 20420   KAFISNLNEM
# 20421    HTVGFILQL
# 20422    VALPMVLVL
# 20423    VALPMVLVL

# %%
filtered_psm_C1203.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_psm_C1203.csv')

# %% [markdown]
# # 4. G0103

# %% [markdown]
# ## Target Peptides

# %%
rescore_peptides_G0103 = pandas.read_csv("/home/thinkpad/HLA_Files/G0103/G0103_Oktoberfest_MSFragger/results/percolator/rescore_target.peptides", sep= '\t')
rescore_peptides_G0103
# Out:
#                                                   PSMId     score   q-value  \
# 0     GN20170722_SK_HLA_G0103_R1_01-7917-ESGPSIVHRKC...  0.952827  0.001435
# 1     GN20170722_SK_HLA_G0103_R1_01-8754-AQYEDIAQKSK...  0.733901  0.001435
# 2     GN20170722_SK_HLA_G0103_R1_02-5552-SELKNM[UNIM...  0.727305  0.001435
# 3     GN20170722_SK_HLA_G0103_R1_01-22761-APLRDPALRQ...  0.698888  0.001435
# 4     GN20170722_SK_HLA_G0103_R1_01-15399-YQAELSQM[U...  0.698210  0.001435
# ...                                                 ...       ...       ...
# 7854  GN20170722_SK_HLA_G0103_R2_01-49582-KRNKVSQEQS... -3.419420  0.776505
# 7855  GN20170722_SK_HLA_G0103_R1_01-49280-VNKKVKKRIQ... -3.449550  0.776505
# 7856  GN20170722_SK_HLA_G0103_R2_02-42861-KKAKKPAATR... -3.498680  0.776505
# 7857  GN20170722_SK_HLA_G0103_R2_01-47932-KKPKATPVKK... -3.566530  0.776661
# 7858  GN20170722_SK_HLA_G0103_R1_01-49227-KAVKPKAAKP... -3.710580  0.776689
#
#       posterior_error_prob                                 peptide  \
# 0                 0.000065              _.ESGPSIVHRKC[UNIMOD:4]F._
# 1                 0.000485                     _.AQYEDIAQKSKAEAE._
# 2                 0.000515  _.SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED._
# 3                 0.000668                        _.APLRDPALRQLL._
# 4                 0.000672          _.YQAELSQM[UNIMOD:35]QTQISET._
# ...                    ...                                     ...
# 7854              1.000000                     _.KRNKVSQEQSKPPGP._
# 7855              1.000000                     _.VNKKVKKRIQLSPKK._
# 7856              1.000000                      _.KKAKKPAATRKSSK._
# 7857              1.000000                          _.KKPKATPVKK._
# 7858              1.000000                      _.KAVKPKAAKPKTAK._
#
#                               proteinIds
# 0                 ESGPSIVHRKC[UNIMOD:4]F
# 1                        AQYEDIAQKSKAEAE
# 2     SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED
# 3                           APLRDPALRQLL
# 4             YQAELSQM[UNIMOD:35]QTQISET
# ...                                  ...
# 7854                     KRNKVSQEQSKPPGP
# 7855                     VNKKVKKRIQLSPKK
# 7856                      KKAKKPAATRKSSK
# 7857                          KKPKATPVKK
# 7858                      KAVKPKAAKPKTAK
#
# [7859 rows x 6 columns]

# %% [markdown]
# ### filter the dataset with FDR = 0.01

# %%
filtered_peptide_G0103 = rescore_peptides_G0103[rescore_peptides_G0103['q-value'] <= 0.01]

# modify the peptide in a new column
filtered_peptide_G0103["modi_peptide"] = filtered_peptide_G0103['peptide']

filtered_peptide_G0103
# Out:
# /tmp/ipykernel_235831/4092363018.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_G0103["modi_peptide"] = filtered_peptide_G0103['peptide']
#                                                   PSMId     score   q-value  \
# 0     GN20170722_SK_HLA_G0103_R1_01-7917-ESGPSIVHRKC...  0.952827  0.001435
# 1     GN20170722_SK_HLA_G0103_R1_01-8754-AQYEDIAQKSK...  0.733901  0.001435
# 2     GN20170722_SK_HLA_G0103_R1_02-5552-SELKNM[UNIM...  0.727305  0.001435
# 3     GN20170722_SK_HLA_G0103_R1_01-22761-APLRDPALRQ...  0.698888  0.001435
# 4     GN20170722_SK_HLA_G0103_R1_01-15399-YQAELSQM[U...  0.698210  0.001435
# ...                                                 ...       ...       ...
# 1624  GN20170722_SK_HLA_G0103_R1_02-4388-KQIVRKLTM[U...  0.135634  0.009822
# 1625  GN20170722_SK_HLA_G0103_R1_01-4536-RRPPTRVHL-3...  0.135456  0.009822
# 1626  GN20170722_SK_HLA_G0103_R2_01-18448-RGPADPVLL-...  0.133673  0.009822
# 1627  GN20170722_SK_HLA_G0103_R2_02-22871-KSPGFGLSL-...  0.133602  0.009822
# 1628  GN20170722_SK_HLA_G0103_R2_02-23541-RIAGLAVSL-...  0.133531  0.009822
#
#       posterior_error_prob                                 peptide  \
# 0                 0.000065              _.ESGPSIVHRKC[UNIMOD:4]F._
# 1                 0.000485                     _.AQYEDIAQKSKAEAE._
# 2                 0.000515  _.SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED._
# 3                 0.000668                        _.APLRDPALRQLL._
# 4                 0.000672          _.YQAELSQM[UNIMOD:35]QTQISET._
# ...                    ...                                     ...
# 1624              0.110414                _.KQIVRKLTM[UNIMOD:35]._
# 1625              0.110580                           _.RRPPTRVHL._
# 1626              0.112253                           _.RGPADPVLL._
# 1627              0.112321                           _.KSPGFGLSL._
# 1628              0.112388                           _.RIAGLAVSL._
#
#                               proteinIds  \
# 0                 ESGPSIVHRKC[UNIMOD:4]F
# 1                        AQYEDIAQKSKAEAE
# 2     SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED
# 3                           APLRDPALRQLL
# 4             YQAELSQM[UNIMOD:35]QTQISET
# ...                                  ...
# 1624                KQIVRKLTM[UNIMOD:35]
# 1625                           RRPPTRVHL
# 1626                           RGPADPVLL
# 1627                           KSPGFGLSL
# 1628                           RIAGLAVSL
#
#                                 modi_peptide
# 0                 _.ESGPSIVHRKC[UNIMOD:4]F._
# 1                        _.AQYEDIAQKSKAEAE._
# 2     _.SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED._
# 3                           _.APLRDPALRQLL._
# 4             _.YQAELSQM[UNIMOD:35]QTQISET._
# ...                                      ...
# 1624                _.KQIVRKLTM[UNIMOD:35]._
# 1625                           _.RRPPTRVHL._
# 1626                           _.RGPADPVLL._
# 1627                           _.KSPGFGLSL._
# 1628                           _.RIAGLAVSL._
#
# [1629 rows x 7 columns]

# %%
filtered_peptide_G0103['modi_peptide'] = filtered_peptide_G0103['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_peptide_G0103['modi_peptide'] = filtered_peptide_G0103['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_peptide_G0103.tail(20)
# Out:
# /tmp/ipykernel_235831/417669660.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_G0103['modi_peptide'] = filtered_peptide_G0103['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/417669660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_peptide_G0103['modi_peptide'] = filtered_peptide_G0103['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                   PSMId     score   q-value  \
# 1609  GN20170722_SK_HLA_G0103_R1_02-18866-KLPKGILL-2...  0.141767  0.009236
# 1610  GN20170722_SK_HLA_G0103_R1_02-31118-KIPAILYL-2...  0.141767  0.009236
# 1611  GN20170722_SK_HLA_G0103_R1_01-31052-TIIANC[UNI...  0.141304  0.009236
# 1612  GN20170722_SK_HLA_G0103_R2_01-13566-KVPGDVSL-2...  0.140590  0.009236
# 1613  GN20170722_SK_HLA_G0103_R1_01-16483-KIHEPIML-2...  0.140555  0.009236
# 1614  GN20170722_SK_HLA_G0103_R1_01-19331-KYPDAVYL-2...  0.140412  0.009236
# 1615  GN20170722_SK_HLA_G0103_R1_01-39196-IFPVVRILL-...  0.139485  0.009236
# 1616  GN20170722_SK_HLA_G0103_R1_02-33656-KLITSFLEL-...  0.138736  0.009236
# 1617  GN20170722_SK_HLA_G0103_R2_01-4468-SKIKGKPVL-3...  0.138344  0.009236
# 1618  GN20170722_SK_HLA_G0103_R1_01-33998-AIILEAVNL-...  0.138166  0.009236
# 1619    GN20170722_SK_HLA_G0103_R1_01-39-KVPQKKVKL-3-25  0.137916  0.009236
# 1620  GN20170722_SK_HLA_G0103_R1_02-29491-KLPPVLVL-2...  0.137239  0.009236
# 1621  GN20170722_SK_HLA_G0103_R2_02-29524-KTPIPLLL-2...  0.137025  0.009236
# 1622  GN20170722_SK_HLA_G0103_R1_02-5426-KSPRALRL-3-...  0.136954  0.009236
# 1623  GN20170722_SK_HLA_G0103_R1_01-6364-PSARTLTHYKS...  0.136954  0.009236
# 1624  GN20170722_SK_HLA_G0103_R1_02-4388-KQIVRKLTM[U...  0.135634  0.009822
# 1625  GN20170722_SK_HLA_G0103_R1_01-4536-RRPPTRVHL-3...  0.135456  0.009822
# 1626  GN20170722_SK_HLA_G0103_R2_01-18448-RGPADPVLL-...  0.133673  0.009822
# 1627  GN20170722_SK_HLA_G0103_R2_02-22871-KSPGFGLSL-...  0.133602  0.009822
# 1628  GN20170722_SK_HLA_G0103_R2_02-23541-RIAGLAVSL-...  0.133531  0.009822
#
#       posterior_error_prob                   peptide            proteinIds  \
# 1609              0.104830              _.KLPKGILL._              KLPKGILL
# 1610              0.104830              _.KIPAILYL._              KIPAILYL
# 1611              0.105244   _.TIIANC[UNIMOD:4]IVL._   TIIANC[UNIMOD:4]IVL
# 1612              0.105882              _.KVPGDVSL._              KVPGDVSL
# 1613              0.105914              _.KIHEPIML._              KIHEPIML
# 1614              0.106042              _.KYPDAVYL._              KYPDAVYL
# 1615              0.106878             _.IFPVVRILL._             IFPVVRILL
# 1616              0.107558             _.KLITSFLEL._             KLITSFLEL
# 1617              0.107915             _.SKIKGKPVL._             SKIKGKPVL
# 1618              0.108078             _.AIILEAVNL._             AIILEAVNL
# 1619              0.108306             _.KVPQKKVKL._             KVPQKKVKL
# 1620              0.108928              _.KLPPVLVL._              KLPPVLVL
# 1621              0.109125              _.KTPIPLLL._              KTPIPLLL
# 1622              0.109191              _.KSPRALRL._              KSPRALRL
# 1623              0.109191       _.PSARTLTHYKSAVKA._       PSARTLTHYKSAVKA
# 1624              0.110414  _.KQIVRKLTM[UNIMOD:35]._  KQIVRKLTM[UNIMOD:35]
# 1625              0.110580             _.RRPPTRVHL._             RRPPTRVHL
# 1626              0.112253             _.RGPADPVLL._             RGPADPVLL
# 1627              0.112321             _.KSPGFGLSL._             KSPGFGLSL
# 1628              0.112388             _.RIAGLAVSL._             RIAGLAVSL
#
#          modi_peptide
# 1609         KLPKGILL
# 1610         KIPAILYL
# 1611        TIIANCIVL
# 1612         KVPGDVSL
# 1613         KIHEPIML
# 1614         KYPDAVYL
# 1615        IFPVVRILL
# 1616        KLITSFLEL
# 1617        SKIKGKPVL
# 1618        AIILEAVNL
# 1619        KVPQKKVKL
# 1620         KLPPVLVL
# 1621         KTPIPLLL
# 1622         KSPRALRL
# 1623  PSARTLTHYKSAVKA
# 1624        KQIVRKLTM
# 1625        RRPPTRVHL
# 1626        RGPADPVLL
# 1627        KSPGFGLSL
# 1628        RIAGLAVSL

# %%
filtered_peptide_G0103.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_peptides_G0103.csv')

# %% [markdown]
# ## Target PSMs

# %%
rescore_psm_G0103 = pandas.read_csv("/home/thinkpad/HLA_Files/G0103/G0103_Oktoberfest_MSFragger/results/percolator/rescore_target.psms", sep= '\t')

rescore_psm_G0103
# Out:
#                                                    PSMId     score   q-value  \
# 0      GN20170722_SK_HLA_G0103_R1_01-7917-ESGPSIVHRKC...  0.952827  0.000176
# 1      GN20170722_SK_HLA_G0103_R2_02-7777-ESGPSIVHRKC...  0.890644  0.000176
# 2      GN20170722_SK_HLA_G0103_R2_01-7777-ESGPSIVHRKC...  0.885902  0.000176
# 3      GN20170722_SK_HLA_G0103_R1_01-8754-AQYEDIAQKSK...  0.733901  0.000176
# 4      GN20170722_SK_HLA_G0103_R1_02-5552-SELKNM[UNIM...  0.727305  0.000176
# ...                                                  ...       ...       ...
# 30287  GN20170722_SK_HLA_G0103_R2_01-49582-KRNKVSQEQS... -3.419420  0.310948
# 30288  GN20170722_SK_HLA_G0103_R1_01-49280-VNKKVKKRIQ... -3.449550  0.310961
# 30289  GN20170722_SK_HLA_G0103_R2_02-42861-KKAKKPAATR... -3.498680  0.310961
# 30290  GN20170722_SK_HLA_G0103_R2_01-47932-KKPKATPVKK... -3.566530  0.311016
# 30291  GN20170722_SK_HLA_G0103_R1_01-49227-KAVKPKAAKP... -3.710580  0.311039
#
#        posterior_error_prob                                 peptide  \
# 0              2.596400e-07              _.ESGPSIVHRKC[UNIMOD:4]F._
# 1              6.226850e-07              _.ESGPSIVHRKC[UNIMOD:4]F._
# 2              6.656410e-07              _.ESGPSIVHRKC[UNIMOD:4]F._
# 3              5.647480e-06                     _.AQYEDIAQKSKAEAE._
# 4              6.196600e-06  _.SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED._
# ...                     ...                                     ...
# 30287          1.000000e+00                     _.KRNKVSQEQSKPPGP._
# 30288          1.000000e+00                     _.VNKKVKKRIQLSPKK._
# 30289          1.000000e+00                      _.KKAKKPAATRKSSK._
# 30290          1.000000e+00                          _.KKPKATPVKK._
# 30291          1.000000e+00                      _.KAVKPKAAKPKTAK._
#
#                                proteinIds
# 0                  ESGPSIVHRKC[UNIMOD:4]F
# 1                  ESGPSIVHRKC[UNIMOD:4]F
# 2                  ESGPSIVHRKC[UNIMOD:4]F
# 3                         AQYEDIAQKSKAEAE
# 4      SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED
# ...                                   ...
# 30287                     KRNKVSQEQSKPPGP
# 30288                     VNKKVKKRIQLSPKK
# 30289                      KKAKKPAATRKSSK
# 30290                          KKPKATPVKK
# 30291                      KAVKPKAAKPKTAK
#
# [30292 rows x 6 columns]

# %% [markdown]
# ### filter the dataset with FDR = 0.01

# %%
filtered_psm_G0103 = rescore_psm_G0103[rescore_psm_G0103['q-value'] <= 0.01]

#modify the peptide in a new column
filtered_psm_G0103["modi_peptide"] = filtered_psm_G0103['peptide']

filtered_psm_G0103
# Out:
# /tmp/ipykernel_235831/3726800591.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_G0103["modi_peptide"] = filtered_psm_G0103['peptide']
#                                                    PSMId     score   q-value  \
# 0      GN20170722_SK_HLA_G0103_R1_01-7917-ESGPSIVHRKC...  0.952827  0.000176
# 1      GN20170722_SK_HLA_G0103_R2_02-7777-ESGPSIVHRKC...  0.890644  0.000176
# 2      GN20170722_SK_HLA_G0103_R2_01-7777-ESGPSIVHRKC...  0.885902  0.000176
# 3      GN20170722_SK_HLA_G0103_R1_01-8754-AQYEDIAQKSK...  0.733901  0.000176
# 4      GN20170722_SK_HLA_G0103_R1_02-5552-SELKNM[UNIM...  0.727305  0.000176
# ...                                                  ...       ...       ...
# 20431  GN20170722_SK_HLA_G0103_R2_02-29853-KVPFPLTL-2...  0.000535  0.009933
# 20432  GN20170722_SK_HLA_G0103_R1_01-24662-KIPSYITDL-...  0.000357  0.009933
# 20433  GN20170722_SK_HLA_G0103_R2_02-21508-GAPPDTLSL-...  0.000214  0.009933
# 20434  GN20170722_SK_HLA_G0103_R2_01-4485-KLAAHDNLKL-...  0.000178  0.009933
# 20435  GN20170722_SK_HLA_G0103_R2_02-5157-RVPKSKLEV-2...  0.000143  0.009933
#
#        posterior_error_prob                                 peptide  \
# 0              2.596400e-07              _.ESGPSIVHRKC[UNIMOD:4]F._
# 1              6.226850e-07              _.ESGPSIVHRKC[UNIMOD:4]F._
# 2              6.656410e-07              _.ESGPSIVHRKC[UNIMOD:4]F._
# 3              5.647480e-06                     _.AQYEDIAQKSKAEAE._
# 4              6.196600e-06  _.SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED._
# ...                     ...                                     ...
# 20431          1.284070e-01                            _.KVPFPLTL._
# 20432          1.286530e-01                           _.KIPSYITDL._
# 20433          1.288510e-01                           _.GAPPDTLSL._
# 20434          1.289000e-01                          _.KLAAHDNLKL._
# 20435          1.289500e-01                           _.RVPKSKLEV._
#
#                                proteinIds  \
# 0                  ESGPSIVHRKC[UNIMOD:4]F
# 1                  ESGPSIVHRKC[UNIMOD:4]F
# 2                  ESGPSIVHRKC[UNIMOD:4]F
# 3                         AQYEDIAQKSKAEAE
# 4      SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED
# ...                                   ...
# 20431                            KVPFPLTL
# 20432                           KIPSYITDL
# 20433                           GAPPDTLSL
# 20434                          KLAAHDNLKL
# 20435                           RVPKSKLEV
#
#                                  modi_peptide
# 0                  _.ESGPSIVHRKC[UNIMOD:4]F._
# 1                  _.ESGPSIVHRKC[UNIMOD:4]F._
# 2                  _.ESGPSIVHRKC[UNIMOD:4]F._
# 3                         _.AQYEDIAQKSKAEAE._
# 4      _.SELKNM[UNIMOD:35]QDM[UNIMOD:35]VED._
# ...                                       ...
# 20431                            _.KVPFPLTL._
# 20432                           _.KIPSYITDL._
# 20433                           _.GAPPDTLSL._
# 20434                          _.KLAAHDNLKL._
# 20435                           _.RVPKSKLEV._
#
# [20436 rows x 7 columns]

# %%
filtered_psm_G0103['modi_peptide'] = filtered_psm_G0103['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
filtered_psm_G0103['modi_peptide'] = filtered_psm_G0103['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)

filtered_psm_G0103.tail(20)
# Out:
# /tmp/ipykernel_235831/2951580749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_G0103['modi_peptide'] = filtered_psm_G0103['modi_peptide'].str.replace('[_,.,:,4,35]', '', regex= True)
# /tmp/ipykernel_235831/2951580749.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_psm_G0103['modi_peptide'] = filtered_psm_G0103['modi_peptide'].str.replace(r'\[UNIMOD\]', '', regex= True)
#                                                    PSMId     score   q-value  \
# 20416  GN20170722_SK_HLA_G0103_R1_02-4443-TPESAGP-1-2975  0.002781  0.009843
# 20417  GN20170722_SK_HLA_G0103_R1_02-22489-AVPVTTIKL-...  0.002567  0.009843
# 20418  GN20170722_SK_HLA_G0103_R2_01-5692-KSPPPM[UNIM...  0.002496  0.009843
# 20419  GN20170722_SK_HLA_G0103_R1_01-6589-EIERMEKQI-3...  0.002460  0.009843
# 20420  GN20170722_SK_HLA_G0103_R1_01-15628-KSPEPLGL-2...  0.002282  0.009843
# 20421  GN20170722_SK_HLA_G0103_R1_02-24237-KVIEINPYL-...  0.002139  0.009889
# 20422  GN20170722_SK_HLA_G0103_R2_01-12447-KIEKLDKLL-...  0.002032  0.009889
# 20423  GN20170722_SK_HLA_G0103_R1_01-25286-KFPIVNAEL-...  0.001925  0.009889
# 20424  GN20170722_SK_HLA_G0103_R1_02-5835-KAPEM[UNIMO...  0.001640  0.009889
# 20425  GN20170722_SK_HLA_G0103_R2_02-19241-KSVDDVVVL-...  0.001426  0.009889
# 20426  GN20170722_SK_HLA_G0103_R1_02-13389-HGIQGKFSL-...  0.001355  0.009889
# 20427  GN20170722_SK_HLA_G0103_R1_01-26860-VVAPAGITL-...  0.001141  0.009933
# 20428  GN20170722_SK_HLA_G0103_R2_02-21642-KVIEEAVYF-...  0.001034  0.009933
# 20429  GN20170722_SK_HLA_G0103_R2_01-23915-KIPSYITDL-...  0.000891  0.009933
# 20430  GN20170722_SK_HLA_G0103_R1_02-24430-KASDLYITL-...  0.000749  0.009933
# 20431  GN20170722_SK_HLA_G0103_R2_02-29853-KVPFPLTL-2...  0.000535  0.009933
# 20432  GN20170722_SK_HLA_G0103_R1_01-24662-KIPSYITDL-...  0.000357  0.009933
# 20433  GN20170722_SK_HLA_G0103_R2_02-21508-GAPPDTLSL-...  0.000214  0.009933
# 20434  GN20170722_SK_HLA_G0103_R2_01-4485-KLAAHDNLKL-...  0.000178  0.009933
# 20435  GN20170722_SK_HLA_G0103_R2_02-5157-RVPKSKLEV-2...  0.000143  0.009933
#
#        posterior_error_prob                   peptide            proteinIds  \
# 20416              0.125330               _.TPESAGP._               TPESAGP
# 20417              0.125620             _.AVPVTTIKL._             AVPVTTIKL
# 20418              0.125717   _.KSPPPM[UNIMOD:35]NL._   KSPPPM[UNIMOD:35]NL
# 20419              0.125766             _.EIERMEKQI._             EIERMEKQI
# 20420              0.126008              _.KSPEPLGL._              KSPEPLGL
# 20421              0.126203             _.KVIEINPYL._             KVIEINPYL
# 20422              0.126349             _.KIEKLDKLL._             KIEKLDKLL
# 20423              0.126495             _.KFPIVNAEL._             KFPIVNAEL
# 20424              0.126885  _.KAPEM[UNIMOD:35]TNEL._  KAPEM[UNIMOD:35]TNEL
# 20425              0.127179             _.KSVDDVVVL._             KSVDDVVVL
# 20426              0.127277             _.HGIQGKFSL._             HGIQGKFSL
# 20427              0.127571             _.VVAPAGITL._             VVAPAGITL
# 20428              0.127718             _.KVIEEAVYF._             KVIEEAVYF
# 20429              0.127914             _.KIPSYITDL._             KIPSYITDL
# 20430              0.128111             _.KASDLYITL._             KASDLYITL
# 20431              0.128407              _.KVPFPLTL._              KVPFPLTL
# 20432              0.128653             _.KIPSYITDL._             KIPSYITDL
# 20433              0.128851             _.GAPPDTLSL._             GAPPDTLSL
# 20434              0.128900            _.KLAAHDNLKL._            KLAAHDNLKL
# 20435              0.128950             _.RVPKSKLEV._             RVPKSKLEV
#
#       modi_peptide
# 20416      TPESAGP
# 20417    AVPVTTIKL
# 20418     KSPPPMNL
# 20419    EIERMEKQI
# 20420     KSPEPLGL
# 20421    KVIEINPYL
# 20422    KIEKLDKLL
# 20423    KFPIVNAEL
# 20424    KAPEMTNEL
# 20425    KSVDDVVVL
# 20426    HGIQGKFSL
# 20427    VVAPAGITL
# 20428    KVIEEAVYF
# 20429    KIPSYITDL
# 20430    KASDLYITL
# 20431     KVPFPLTL
# 20432    KIPSYITDL
# 20433    GAPPDTLSL
# 20434   KLAAHDNLKL
# 20435    RVPKSKLEV

# %%
filtered_psm_G0103.to_csv('/home/thinkpad/HLA_Files/OK_MSfragger_filtered/filtered_target_psm_G0103.csv')
